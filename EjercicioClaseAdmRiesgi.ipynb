# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanJCL/ProyectoPrueba/blob/main/EjercicioClaseAdmRiesgi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Información de las acciones
#nombre de las acciones
#creamos una variable
#nombre_acciones = ["BIMBOA.MX"]

#PERIODO DE LA INFORMACIÓN
recolector = []

#iniciamos con un for que itere sobre cada activo
for nombre in nombre_acciones:
    #creamos un objeto
    #tCIKER ES EL IDENTIFICADOR DE LACCION

    ticker = yf.Ticker(nombre)

    #uTILIZAMOS HISTORY
    px = ticker.history(period="y")
    #Asignar el nombre de los precios descargados (funciona como una especie de id)
    px.name = nombre
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8b75d3654b2c> in <cell line: 0>()
#       8
#       9 #iniciamos con un for que itere sobre cada activo
# ---> 10 for nombre in nombre_acciones:
#      11     #creamos un objeto
#      12     #tCIKER ES EL IDENTIFICADOR DE LACCION
#
# NameError: name 'nombre_acciones' is not defined

# %%
nombre_acciones = ["SORIANA.MX", "AZTECA.MX", "BANORTE.MX", "PEÑOLES.MX"]

# %%
recolector = []


# Crea una lista con los datos
datos_soriana = [31.32, 31.59, 31.78, 31.75, 31.65, 31, 30.9, 30.81, 30.9, 30.99, 30.9, 30.84, 30.12, 30.8, 30.77, 30.56, 30, 30.11, 30.56, 31.3, 30.92, 30.55, 30.5, 30.02, 30.02, 29.69, 29.7, 30.29, 30.7, 30.67, 30.56, 30.45, 29.5, 30, 30, 30, 30.4, 30.2, 30.2, 30.4, 30.01, 30.1, 30.07, 30.7, 30.7, 30.4, 30.21, 29.85, 29.85, 30.26, 30.95, 29.5, 30.5, 30.5, 29.92, 30.1, 30.55, 30.51, 30.51, 30.5, 30.55, 30.76, 31, 30.1, 30.2, 30.8, 30.99, 31, 30.99, 31, 31, 30.99, 30.84, 30.99, 30.7, 30.6, 30.99, 30.89, 31.29, 30.5, 31.13]
# Crea un Series de pandas con los datos
sr_soriana = pd.Series(datos_soriana, name='SORIANA')


# Crea una lista con los datos de Azteca
datos_azteca = [0.8, 0.82, 0.82, 0.85, 0.83, 0.82, 0.82, 0.82, 0.82, 0.82, 0.83, 0.82, 0.8, 0.81, 0.81, 0.8, 0.78, 0.79, 0.8, 0.82, 0.8, 0.8, 0.81, 0.79, 0.8, 0.78, 0.8, 0.8, 0.8, 0.79, 0.79, 0.81, 0.8, 0.8, 0.8, 0.79, 0.78, 0.79, 0.78, 0.77, 0.74, 0.75, 0.77, 0.77, 0.79, 0.77, 0.78, 0.78, 0.78, 0.77, 0.77, 0.76, 0.76, 0.74, 0.72, 0.48, 0.66, 0.68, 0.65, 0.68, 0.63, 0.64, 0.66, 0.67, 0.64, 0.65, 0.6, 0.6, 0.61, 0.63, 0.62, 0.63, 0.62, 0.62, 0.6, 0.58, 0.61, 0.61, 0.56, 0.54, 0.53]
# Crea un DataFrame de pandas con los datos
sr_azteca = pd.Series(datos_azteca, name='AZTECA')


# Crea una lista con los datos de BANORTE
datos_banorte = [142.85, 142.5, 145.85, 145.4, 150.76, 154.05, 153.57, 154.5, 155.7, 157.44, 155.55, 155.85, 153.57, 154, 154.74, 156.87, 159, 157.6, 155.69, 155.9, 155.69, 156, 157.5, 152.49, 153.43, 153.85, 153.46, 153.88, 155.04, 155.7, 156.78, 162.79, 164, 162.6, 164.05, 159, 154.56, 157.71, 156.63, 155.97, 154.88, 161.54, 158.09, 159.97, 161.22, 158.26, 160.7, 163.25, 163.25, 148.01, 144.81, 137.8, 149.15, 145.07, 150.93, 150.21, 151.8, 149, 143.59, 142.85, 149, 149.21, 151.72, 150.68, 152.53, 150.08, 149.75, 150.07, 145.65, 147.35, 147.57, 150.49, 150.07, 152.59, 153.03, 151.12, 158.7, 157.24, 150.6, 153, 155.82]
# Crea un DataFrame de pandas con los datos
sr_banorte = pd.Series(datos_banorte, name='BANORTE')


# Crea una lista con los datos de Peñoles
datos_peñoles = [245.95, 264, 287.13, 284.8, 293.4, 292.93, 292.79, 294.53, 293.3, 294.47, 294.88, 285.5, 286.5, 286.01, 287.71, 285.84, 287.2, 289.98, 283.51, 274.66, 268.09, 266.19, 269.72, 267.44, 264.21, 254.5, 257.04, 249.79, 243.01, 244.19, 237.45, 237.27, 235.83, 238.99, 238.21, 237.1, 234.01, 234.05, 230.26, 228.12, 218.91, 232.29, 228, 234.74, 231.39, 219.91, 220.74, 221.14, 221.14, 236.18, 237.75, 243.95, 237.5, 259.56, 257.7, 259.97, 258.88, 258.27, 258.49, 270.49, 260.61, 269, 268.2, 261.51, 273.17, 266.37, 270.97, 280.73, 280.99, 284, 278.75, 279.79, 278.78, 274.72, 273.81, 276.85, 281.5, 285.84, 279.64, 275.2, 278]
# Crea un DataFrame de pandas con los datos
sr_peñoles = pd.Series(datos_peñoles, name='PEÑOLES')


recolector += [sr_soriana, sr_azteca, sr_banorte, sr_peñoles]


precios = pd.concat(recolector, axis=1)

# %%
#rellenemos los valores NAN
precios = precios.ffill()
#bfill
#ffill

#¿Cuanto vamos a invertir?
monto_inversion = 1000
monto_inversion2 = '${:,f}'.format(monto_inversion)

# %%
#nivel de confianza
nivel_de_confianza = 99
print("Nivel de confianza del: ", nivel_de_confianza, "%")
# Out:
# Nivel de confianza del:  99 %

# %%
#precio actual
precio_actual = precios.iloc[-1]

# %%
#precio actual
precio_actual_activos = precios.iloc[-1]
#convertimos  de pd.series a pd.frame
precio_activos = precio_actual_activos.squeeze()
precio_activos_dinero = precio_activos.apply('${:,f}'.format)

# %%
#rendimiento Ln(i/i-1)
#.shift desplaza una fila hacia abajo
rendimientos = np.log(precios / precios.shift(1))
rendimientos
# Out:
#      SORIANA    AZTECA   BANORTE   PEÑOLES
# 0        NaN       NaN       NaN       NaN
# 1   0.008584  0.024693 -0.002453  0.070821
# 2   0.005997  0.000000  0.023237  0.083986
# 3  -0.000944  0.035932 -0.003090 -0.008148
# 4  -0.003155 -0.023811  0.036201  0.029750
# ..       ...       ...       ...       ...
# 76  0.012665  0.050431  0.048941  0.016657
# 77 -0.003232  0.000000 -0.009242  0.015300
# 78  0.012866 -0.085522 -0.043146 -0.021929
# 79 -0.025572 -0.036368  0.015811 -0.016005
# 80  0.020445 -0.018692  0.018264  0.010123
#
# [81 rows x 4 columns]

# %%
#Quitamos el NA con droppna
rendimientos.dropna(inplace=True)
rendimientos
# Out:
#      SORIANA    AZTECA   BANORTE   PEÑOLES
# 1   0.008584  0.024693 -0.002453  0.070821
# 2   0.005997  0.000000  0.023237  0.083986
# 3  -0.000944  0.035932 -0.003090 -0.008148
# 4  -0.003155 -0.023811  0.036201  0.029750
# 5  -0.020751 -0.012121  0.021588 -0.001603
# ..       ...       ...       ...       ...
# 76  0.012665  0.050431  0.048941  0.016657
# 77 -0.003232  0.000000 -0.009242  0.015300
# 78  0.012866 -0.085522 -0.043146 -0.021929
# 79 -0.025572 -0.036368  0.015811 -0.016005
# 80  0.020445 -0.018692  0.018264  0.010123
#
# [80 rows x 4 columns]

# %%
#numero de dias cotizados y numeor de activos
num_filas = len(rendimientos.axes[0])
num_columnas = len(rendimientos.axes[1])

# %%
#esperanzas
#obtener el promedio
esperanza_activo = rendimientos.mean()

print(esperanza_activo)
# Out:
# SORIANA   -0.000076
# AZTECA    -0.005147
# BANORTE    0.001086
# PEÑOLES    0.001531
# dtype: float64

# %%
#lo convertimos en procentaje
esperanza_activo_porcentaje = esperanza_activo * 100
#print(esperanza_activo_porcentaje)

esperanza_activo_procentaje = esperanza_activo_porcentaje.apply('{:,.5f}%'.format)
print(esperanza_activo_procentaje)
# Out:
# SORIANA    -0.00761%
# AZTECA     -0.51467%
# BANORTE     0.10863%
# PEÑOLES     0.15312%
# dtype: object

# %%
#esperanzas
#obtener el promedio
varianza_activo = rendimientos.std()

#lo convertimos en procentaje
varianza_activo_porcentaje = varianza_activo * 100
#print(esperanza_activo_porcentaje)

varianza_activo_procentaje = varianza_activo_porcentaje.apply('{:,.2f}%'.format)
varianza_activo_porcentaje
# Out:
# SORIANA    1.343317
# AZTECA     6.326592
# BANORTE    2.368335
# PEÑOLES    2.656522
# dtype: float64

# %%
#esperanza y riesgo en una tabla
df_activos = pd.DataFrame(columns = nombre_acciones , index = ["Esperanza activo", "Riesgo del activo"])
df_activos.loc["Esperanza activo"] = esperanza_activo_procentaje
df_activos.loc["Riesgo del activo"] = varianza_activo_procentaje
df_activos.T
# Out:
#            Esperanza activo Riesgo del activo
# SORIANA.MX              NaN               NaN
# AZTECA.MX               NaN               NaN
# BANORTE.MX              NaN               NaN
# PEÑOLES.MX              NaN               NaN

# %%
tasa_cetes = 0.10/252
excedentes_rend = esperanza_activo - tasa_cetes

# %%
from re import M
matriz_var_principal=np.cov(rendimientos, y= None, rowvar = 0, bias = True, ddof = None, aweights = None)

matriz_var1 = np.insert(matriz_var_principal, num_columnas, 1, axis =1)
matriz_var1 = np.insert(matriz_var1, num_columnas, 1, axis =0)
#matriz_var1

matriz_var1 [num_columnas, num_columnas] = '0'
#matriz_var1

matriz_var_inversa = np.linalg.inv(matriz_var1)
matriz_var_inversa
# Out:
# array([[ 2.57781975e+03, -1.56504643e+02, -1.32925984e+03,
#         -1.09205526e+03,  6.21966006e-01],
#        [-1.56504643e+02,  2.58570200e+02, -7.98459256e+01,
#         -2.22196310e+01,  6.27066929e-03],
#        [-1.32925984e+03, -7.98459256e+01,  1.51954537e+03,
#         -1.10439595e+02,  2.03138310e-01],
#        [-1.09205526e+03, -2.22196310e+01, -1.10439595e+02,
#          1.22471448e+03,  1.68625015e-01],
#        [ 6.21966006e-01,  6.27066929e-03,  2.03138310e-01,
#          1.68625015e-01, -1.21630113e-04]])

# %%
#PRD

#ESPERANZA
#NP. LAS ESPERANZA

esperanza = np.array(esperanza_activo)
esperanza_0 = np.insert(esperanza, num_columnas, [0], axis = 0)


esperanza_0s = np.insert(esperanza_0, num_columnas, [0], axis = 0)

matriz_rend = np.insert(matriz_var1, num_columnas + 1, esperanza_0, axis =1)
matriz_rend = np.insert(matriz_rend, num_columnas+1, esperanza_0s, axis=0)

rend_deseado = 0.00078

matriz_rend_inv = np.linalg.inv(matriz_rend)

#ultima col inv rend

matriz_solorend =  matriz_rend_inv[-1]
#redniminento deseado
matriz_rendesp = matriz_solorend * rend_deseado

matriz_resp = matriz_rend_inv[-2]

suma_matriz_resp = matriz_rendesp + matriz_resp

wi_rend_des = suma_matriz_resp[:num_columnas]

#corroborar
esp_port = np.matmul(wi_rend_des,esperanza_activo)

esp_port_porcent = esp_port * 100
esp_port_porcent = '{:,.5f}%'.format(esp_port_porcent)

var_port_des = np.square(np.matmul(wi_rend_des, np.matmul(matriz_var_principal, wi_rend_des)))
var_port_des = var_port_des * 100
var_port_des = '{:,.10f}%'.format(var_port_des)
var_port_des

#DF asignaciones

df_wi_esp = pd.DataFrame(columns = nombre_acciones , index = ["asignación"])
df_wi_esp.loc["asignación"] = wi_rend_des
df_wi_esp.T
# Out:
#            asignación
# SORIANA.MX   0.547149
# AZTECA.MX   -0.036698
# BANORTE.MX   0.262643
# PEÑOLES.MX   0.226906
